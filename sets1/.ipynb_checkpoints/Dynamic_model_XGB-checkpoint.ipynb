# %%
import pickle
import joblib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from kafka import KafkaConsumer
from sklearn.metrics import f1_score
import copy
from collections import deque
from sklearn.metrics import (f1_score, precision_score, recall_score, 
                             confusion_matrix, roc_curve, auc,
                             precision_recall_curve, average_precision_score)

# %%
with open('scaler.pkl', 'rb') as scaler_file:
    scaler = joblib.load(scaler_file)

with open('D:/Documents/GitHub/Final_Project/sets1/models/XGB_model.pkl','rb') as model_file:
    xgb_model = pickle.load(model_file)

print("Scaler and XGB model loaded successfully!")
# Out:
# Scaler and XGB model loaded successfully!

# %%
#Load data stream
consumer = KafkaConsumer(
    'ml-raw-dns',
    bootstrap_servers="localhost:9092",
    auto_offset_reset='earliest',
    enable_auto_commit=False,
    consumer_timeout_ms=5000
)

if consumer.bootstrap_connected():
    print("Successfully connected to Kafka broker")
else:
    print("Couldn't connect to bootstrap server.")
# Out:
# Successfully connected to Kafka broker

# %%
def scale_features(df, feature_cols):
    X = df[feature_cols]
    # Transform
    X_scaled = scaler.transform(X)
    
    # Put back into DataFrame
    scaled_df = pd.DataFrame(X_scaled, columns=feature_cols, index=df.index)
    
    # Reattach label if it exists
    if 'label' in df.columns:
        scaled_df['label'] = df['label']
    return scaled_df

# %%
def plot_roc_curve(actual_vals, pred_probs, model_name="XGB Model"):
    fpr, tpr, _ = roc_curve(actual_vals, pred_probs)
    auc_score = auc(fpr, tpr)
    
    plt.figure()
    plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {auc_score:.2f})')
    plt.plot([0, 1], [0, 1], linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC AUC Curve for {model_name}')
    plt.legend(loc='lower right')
    plt.show()

def plot_precision_recall_curve(actual_vals, pred_probs, model_name="XGB Model"):
    precision, recall, _ = precision_recall_curve(actual_vals, pred_probs)
    avg_precision = average_precision_score(actual_vals, pred_probs)
    
    plt.figure()
    plt.plot(recall, precision, label=f'PR Curve (Avg Precision = {avg_precision:.2f})')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title(f'Precision-Recall Curve for {model_name}')
    plt.legend(loc='lower left')
    plt.show()

# %%
static_model = xgb_model
dynamic_model = copy.deepcopy(xgb_model)

# %%
feature_columns = scaler.feature_names_in_  # list of feature column names
window_size = 100
max_window_steps = 15
window_count = 0
window_data = deque(maxlen=window_size)

dynamic_model_f1 = []
static_model_f1 = []

print("Starting to consume messages...")

for idx, message in enumerate(consumer):
    # Decode and split the incoming message
    row = message.value.decode().strip().split(',')
    
    try:
        row_df = pd.DataFrame([row], columns=[*feature_columns, 'label'])
    except ValueError:
        print(f"Skipping invalid row: {row}")
        continue
    
    if 'Unnamed: 0' in row_df.columns:
        row_df.drop('Unnamed: 0', axis=1, inplace=True)
    
    if 'label' in row_df.columns:
        row_df['label'] = row_df['label'].apply(lambda x: x.strip().replace('\\n"', '').replace('"', ''))
        # Ensure the 'label' column contains valid integers
        row_df = row_df[pd.to_numeric(row_df['label'], errors='coerce').notnull()]
        if row_df.empty:
            print(f"Skipping row with invalid label: {row}")
            continue
        row_df['label'] = row_df['label'].astype(int)
    
    for col in feature_columns:
        row_df[col] = pd.to_numeric(row_df[col], errors='coerce').fillna(0)
    
    row_df_scaled = scale_features(row_df, feature_columns)
    
    X_new = row_df_scaled[feature_columns].values  # shape: [1, n_features]
    y_new = int(row_df_scaled['label'].values[0])

    dynamic_pred = dynamic_model.predict(X_new)[0]
    static_pred = static_model.predict(X_new)[0]
    
    window_data.append((X_new[0], y_new, dynamic_pred, static_pred))
    
    if idx % 100 == 0:
        print(f"Consumed {idx} messages")
    
    if len(window_data) == window_size:
        # Extract ground truth and predictions from the window
        y_true = [entry[1] for entry in window_data]
        dynamic_preds = [entry[2] for entry in window_data]
        static_preds = [entry[3] for entry in window_data]
        
        # Compute the weighted F1-score
        current_dynamic_f1 = f1_score(y_true, dynamic_preds, average='weighted')
        current_static_f1 = f1_score(y_true, static_preds, average='weighted')

        current_dynamic_precision = precision_score(y_true, dynamic_preds, average='weighted')
        current_dynamic_recall = recall_score(y_true, dynamic_preds, average='weighted')

        cm = confusion_matrix(y_true, dynamic_preds)

        if cm.shape == (2, 2):
            TN, FP, FN, TP = cm.ravel()
            false_positive_rate = FP / (FP + TN) if (FP + TN) > 0 else 0
        else:
            false_positive_rate = None

        fpr, tpr, _ = roc_curve(y_true, dynamic_preds)
        roc_auc = auc(fpr, tpr)

        print(f"\nWindow complete:")
        print(f"  Dynamic Model -> F1: {current_dynamic_f1:.3f}, Precision: {current_dynamic_precision:.3f}, Recall: {current_dynamic_recall:.3f}, ", end='')
        if false_positive_rate is not None:
            print(f"FPR: {false_positive_rate:.3f}, ROC-AUC: {roc_auc:.3f}")
        else:
            print(f"ROC-AUC: {roc_auc:.3f}")
        print(f"  Static Model  -> F1: {current_static_f1:.3f}")
        
        dynamic_model_f1.append(current_dynamic_f1)
        static_model_f1.append(current_static_f1)

        # Retrain if the F1-score is below the threshold and we haven't exceeded max retrains
        if current_dynamic_f1 < 0.85:
            print(f"Dynamic model F1 ({current_dynamic_f1:.3f}) is below threshold. Retraining dynamic model on this window...")
            X_window = np.array([entry[0] for entry in window_data])
            y_window = np.array([entry[1] for entry in window_data])
            
            dynamic_model.fit(X_window, y_window)
            retrain_count += 1

        # Clear the window for the next batch
        window_data.clear()
        window_count += 1
        if window_count >= max_window_steps:
            print(f"Reached max window steps ({max_window_steps}). Exiting...")
            break

print("Finished streaming from Kafka or timed out.")
# Out:
# Starting to consume messages...
# Consumed 0 messages
# d:\Documents\GitHub\Final_Project\venv\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Window complete:
#   Dynamic Model -> F1: 0.525, Precision: 0.436, Recall: 0.660, FPR: 0.000, ROC-AUC: 0.500
#   Static Model  -> F1: 0.525
# Dynamic model F1 (0.525) is below threshold. Retraining dynamic model on this window...
# Consumed 100 messages
#
# Window complete:
#   Dynamic Model -> F1: 0.898, Precision: 0.900, Recall: 0.900, FPR: 0.046, ROC-AUC: 0.877
#   Static Model  -> F1: 0.512
# Consumed 200 messages
#
# Window complete:
#   Dynamic Model -> F1: 0.889, Precision: 0.892, Recall: 0.890, FPR: 0.050, ROC-AUC: 0.875
#   Static Model  -> F1: 0.450
# Consumed 300 messages
#
# Window complete:
#   Dynamic Model -> F1: 0.970, Precision: 0.971, Recall: 0.970, FPR: 0.000, ROC-AUC: 0.952
#   Static Model  -> F1: 0.563
# Consumed 400 messages
#
# Window complete:
#   Dynamic Model -> F1: 0.909, Precision: 0.910, Recall: 0.910, FPR: 0.046, ROC-AUC: 0.891
#   Static Model  -> F1: 0.512
# Consumed 500 messages
#
# Window complete:
#   Dynamic Model -> F1: 0.869, Precision: 0.869, Recall: 0.870, FPR: 0.088, ROC-AUC: 0.847
#   Static Model  -> F1: 0.550
# Consumed 600 messages
#
# Window complete:
#   Dynamic Model -> F1: 0.889, Precision: 0.889, Recall: 0.890, FPR: 0.062, ROC-AUC: 0.869
#   Static Model  -> F1: 0.512
# Consumed 700 messages
#
# Window complete:
#   Dynamic Model -> F1: 0.919, Precision: 0.919, Recall: 0.920, FPR: 0.043, ROC-AUC: 0.895
#   Static Model  -> F1: 0.576
# Consumed 800 messages
#
# Window complete:
#   Dynamic Model -> F1: 0.941, Precision: 0.942, Recall: 0.940, FPR: 0.054, ROC-AUC: 0.935
#   Static Model  -> F1: 0.629
# Consumed 900 messages
#
# Window complete:
#   Dynamic Model -> F1: 0.900, Precision: 0.900, Recall: 0.900, FPR: 0.078, ROC-AUC: 0.891
#   Static Model  -> F1: 0.500
# Consumed 1000 messages
#
# Window complete:
#   Dynamic Model -> F1: 0.950, Precision: 0.950, Recall: 0.950, FPR: 0.030, ROC-AUC: 0.941
#   Static Model  -> F1: 0.525
# Consumed 1100 messages
#
# Window complete:
#   Dynamic Model -> F1: 0.898, Precision: 0.900, Recall: 0.900, FPR: 0.045, ROC-AUC: 0.872
#   Static Model  -> F1: 0.538
# Consumed 1200 messages
#
# Window complete:
#   Dynamic Model -> F1: 0.881, Precision: 0.882, Recall: 0.880, FPR: 0.104, ROC-AUC: 0.872
#   Static Model  -> F1: 0.538
# Consumed 1300 messages
#
# Window complete:
#   Dynamic Model -> F1: 0.940, Precision: 0.940, Recall: 0.940, FPR: 0.047, ROC-AUC: 0.935
#   Static Model  -> F1: 0.500
# Consumed 1400 messages
#
# Window complete:
#   Dynamic Model -> F1: 0.848, Precision: 0.847, Recall: 0.850, FPR: 0.086, ROC-AUC: 0.807
#   Static Model  -> F1: 0.576
# Dynamic model F1 (0.848) is below threshold. Retraining dynamic model on this window...
# Reached max window steps (15). Exiting...
# Finished streaming from Kafka or timed out.

# %%
import matplotlib.pyplot as plt

# Plotting F1 scores per window
plt.figure(figsize=(10, 6))
plt.plot(dynamic_model_f1, label='Dynamic Model F1 Score', marker='o')
plt.plot(static_model_f1, label='Static Model F1 Score', marker='x')
plt.xlabel('Window Number')
plt.ylabel('F1 Score')
plt.title('F1 Score per Window')
plt.legend()
plt.grid(True)
plt.show()
